# %%
# %run ./utils.ipynb

# %%
csv_path = "Agregados_por_setores_cor_ou_raca_BR_csv/Agregados_por_setores_cor_ou_raca_BR.csv"

# %%
dummy_dinamico = False

# %% [markdown]
# # Porto Alegre

# %%
estado = 'RS'
municipio = '4314902'

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
seg_profile_mun(shp_path, csv_path, municipio, plot_dinamico = dummy_dinamico)
# Out:
# C:\Users\renan\anaconda3\Lib\site-packages\pyogrio\core.py:36: RuntimeWarning: Could not detect PROJ data files. Set PROJ_LIB environment variable to the correct path.
#   _init_proj_data()
# C:\Users\renan\AppData\Local\Temp\ipykernel_41548\3701015944.py:15: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, sep = ';', usecols=desired_columns)
# C:\Users\renan\AppData\Local\Temp\ipykernel_41548\3701015944.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_gdf = merged_gdf.fillna(0)
# C:\Users\renan\anaconda3\Lib\site-packages\segregation\singlegroup\spatial_dissim.py:48: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w_object = Queen.from_dataframe(data)
# Dissimilarity: 0.36938877371482537
# Spatial Dissimilarity: 0.2862184030564052
# Gini: 0.48854095748836385
# Entropy: 0.12980799191107342
# Isolation: 0.36469467525756316
# Dist. Decay Isolation: 0.32391461781522224
# Rel. Concentration: -0.10650809891200008
# Rel. Centralization: -0.10156531362133592
# Rel. Clustering: 0.5956711862979596

# %% [markdown]
# # Belo Horizonte

# %%
estado = 'MG'
municipio = '3106200'

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
seg_profile_mun(shp_path, csv_path, municipio, plot_dinamico = dummy_dinamico)
# Out:
# C:\Users\renan\AppData\Local\Temp\ipykernel_41548\3701015944.py:15: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, sep = ';', usecols=desired_columns)
# C:\Users\renan\AppData\Local\Temp\ipykernel_41548\3701015944.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_gdf = merged_gdf.fillna(0)
# C:\Users\renan\anaconda3\Lib\site-packages\segregation\singlegroup\spatial_dissim.py:48: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w_object = Queen.from_dataframe(data)
# Dissimilarity: 0.35021414807515844
# Spatial Dissimilarity: 0.2586190128446201
# Gini: 0.4688072276234917
# Entropy: 0.13291743725484428
# Isolation: 0.6371511245689692
# Dist. Decay Isolation: 0.607040098693925
# Rel. Concentration: -0.10820249686750398
# Rel. Centralization: -0.23376004234933134
# Rel. Clustering: 0.05068193006799282

# %% [markdown]
# # São Paulo

# %%
estado = 'SP'
municipio = '3550308'

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
seg_profile_mun(shp_path, csv_path, municipio, plot_dinamico = dummy_dinamico)
# Out:
# C:\Users\renan\AppData\Local\Temp\ipykernel_41548\3701015944.py:15: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, sep = ';', usecols=desired_columns)
# C:\Users\renan\AppData\Local\Temp\ipykernel_41548\3701015944.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_gdf = merged_gdf.fillna(0)
# C:\Users\renan\anaconda3\Lib\site-packages\segregation\singlegroup\spatial_dissim.py:48: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w_object = Queen.from_dataframe(data)
# Dissimilarity: 0.3398172360204867
# Spatial Dissimilarity: 0.2348804947548332
# Gini: 0.45562522324826166
# Entropy: 0.12483947527466109
# Isolation: 0.5233691348393611
# Dist. Decay Isolation: 0.48471768954446676
# Rel. Concentration: -0.020331429031083845
# Rel. Centralization: -0.3029313482466023
# Rel. Clustering: 0.289159771315173

# %% [markdown]
# # Rio de Janeiro

# %%
estado = 'RJ'
municipio = '3304557'

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
seg_profile_mun(shp_path, csv_path, municipio, plot_dinamico = dummy_dinamico)
# Out:
# C:\Users\renan\AppData\Local\Temp\ipykernel_41548\3701015944.py:15: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, sep = ';', usecols=desired_columns)
# C:\Users\renan\AppData\Local\Temp\ipykernel_41548\3701015944.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_gdf = merged_gdf.fillna(0)
# C:\Users\renan\anaconda3\Lib\site-packages\segregation\singlegroup\spatial_dissim.py:48: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w_object = Queen.from_dataframe(data)
# C:\Users\renan\anaconda3\Lib\site-packages\libpysal\weights\contiguity.py:347: UserWarning: The weights matrix is not fully connected:
#  There are 12 disconnected components.
#  There are 8 islands with ids: 45, 64, 201, 213, 1721, 9884, 10503, 10740.
#   W.__init__(self, neighbors, ids=ids, **kw)
# Dissimilarity: 0.3253935055738669
# Spatial Dissimilarity: 0.21646933579708993
# Gini: 0.4398175472132027
# Entropy: 0.11896272805644524
# Isolation: 0.6132643343191939
# Dist. Decay Isolation: 0.5919064651077041
# Rel. Concentration: -0.04318729141878447
# Rel. Centralization: 0.0067274824732521665
# Rel. Clustering: 0.10109031742371588

# %% [markdown]
# # Florianópolis

# %%
estado = 'SC'
municipio = '4205407'

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
seg_profile_mun(shp_path, csv_path, municipio, plot_dinamico = dummy_dinamico)
# Out:
# C:\Users\renan\AppData\Local\Temp\ipykernel_41548\3701015944.py:15: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, sep = ';', usecols=desired_columns)
# C:\Users\renan\AppData\Local\Temp\ipykernel_41548\3701015944.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_gdf = merged_gdf.fillna(0)
# C:\Users\renan\anaconda3\Lib\site-packages\segregation\singlegroup\spatial_dissim.py:48: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w_object = Queen.from_dataframe(data)
# C:\Users\renan\anaconda3\Lib\site-packages\libpysal\weights\contiguity.py:347: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#  There are 2 islands with ids: 541, 604.
#   W.__init__(self, neighbors, ids=ids, **kw)
# Dissimilarity: 0.306466039563185
# Spatial Dissimilarity: 0.2051016447353399
# Gini: 0.42710302822155355
# Entropy: 0.10064245592552766
# Isolation: 0.3145285038468544
# Dist. Decay Isolation: 0.2895063862527806
# Rel. Concentration: 0.0702158956107623
# Rel. Centralization: -0.054072515077052685
# Rel. Clustering: 0.5879370196962455
