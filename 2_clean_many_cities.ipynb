# %%
# %run ./utils.ipynb

# %%
csv_path = "Agregados_por_setores_cor_ou_raca_BR_csv/Agregados_por_setores_cor_ou_raca_BR.csv"

# %% [markdown]
# # Porto Alegre

# %%
estado = 'RS'
municipio = '4314902'

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
seg_profile_mun(shp_path, csv_path, municipio, plot_dinamico = True)

# %% [markdown]
# # Belo Horizonte

# %%
estado = 'MG'
municipio = '3106200'

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
seg_profile_mun(shp_path, csv_path, municipio, plot_dinamico = True)

# %% [markdown]
# # São Paulo

# %%
estado = 'SP'
municipio = '3550308'

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
seg_profile_mun(shp_path, csv_path, municipio, plot_dinamico = True)

# %% [markdown]
# # Rio de Janeiro

# %%
estado = 'RJ'
municipio = '3304557'

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
seg_profile_mun(shp_path, csv_path, municipio, plot_dinamico = True)

# %% [markdown]
# # Florianópolis

# %%
estado = 'SC'
municipio = '4205407'

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
seg_profile_mun(shp_path, csv_path, municipio, plot_dinamico = True)
