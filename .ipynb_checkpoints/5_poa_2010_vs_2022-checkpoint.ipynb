# %%
# %run ./utils.ipynb

# %%
n_iteracoes = 500
n_jobs = -1
backend = "loky"

# %%
estado = 'RS'
municipio = '4314902' # Porto Alegre
#municipio = '4314100' # Passo Fundo
dummy_dinamico = False

shp_path_2022 = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
shp_path_2010 = "rs_setores_censitarios/43SEE250GC_SIR.shp"

# %%
csv_path_2010 = "RS_20241211/Base informaçoes setores2010 universo RS/CSV/Pessoa03_RS.csv"
csv_path_2022 = "Agregados_por_setores_cor_ou_raca_BR_csv/Agregados_por_setores_cor_ou_raca_BR.csv"

# %%
merged_df_2010 = process_mun_2010(shp_path_2010, csv_path_2010, municipio)
merged_df_2022 = process_mun(shp_path_2022, csv_path_2022, municipio)
# Out:
# C:\Users\renan\AppData\Local\Temp\ipykernel_46700\2500115525.py:22: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_gdf = merged_gdf.fillna(0)
# C:\Users\renan\AppData\Local\Temp\ipykernel_46700\3373739213.py:15: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, sep = ';', usecols=desired_columns)
# C:\Users\renan\AppData\Local\Temp\ipykernel_46700\3373739213.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_gdf = merged_gdf.fillna(0)

# %%
all_segs_2010 = calculate_seg(merged_df_2010)
all_segs_2022 = calculate_seg(merged_df_2022)
# Out:
# C:\Users\renan\anaconda3\Lib\site-packages\segregation\singlegroup\spatial_dissim.py:48: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w_object = Queen.from_dataframe(data)
# C:\Users\renan\anaconda3\Lib\site-packages\libpysal\weights\contiguity.py:347: UserWarning: The weights matrix is not fully connected:
#  There are 4 disconnected components.
#   W.__init__(self, neighbors, ids=ids, **kw)
# Dissimilarity: 0.3885615637028357
# Spatial Dissimilarity: 0.3150781221720164
# Gini: 0.5146171267331526
# Entropy: 0.1390894113530435
# Isolation: 0.31162727148361247
# Dist. Decay Isolation: 0.26770542731274505
# Rel. Concentration: -0.007392864178989922
# Rel. Centralization: -0.08735180351607141
# Rel. Clustering: 0.8659936499221979
# C:\Users\renan\anaconda3\Lib\site-packages\segregation\singlegroup\spatial_dissim.py:48: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w_object = Queen.from_dataframe(data)
# Dissimilarity: 0.36938877371482537
# Spatial Dissimilarity: 0.2862184030564052
# Gini: 0.48854095748836385
# Entropy: 0.12980799191107342
# Isolation: 0.36469467525756316
# Dist. Decay Isolation: 0.32391461781522224
# Rel. Concentration: -0.10650809891200008
# Rel. Centralization: -0.10156531362133592
# Rel. Clustering: 0.5956711862979596

# %%
approach = 'random_label'
graph_file_name = f"grid_plot_{municipio}_{approach}_2010_vs_2022.png"

compare_0 = inference.TwoValueTest(all_segs_2010[0], all_segs_2022[0], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_1 = inference.TwoValueTest(all_segs_2010[1], all_segs_2022[1], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_2 = inference.TwoValueTest(all_segs_2010[2], all_segs_2022[2], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_3 = inference.TwoValueTest(all_segs_2010[3], all_segs_2022[3], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_4 = inference.TwoValueTest(all_segs_2010[4], all_segs_2022[4], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_5 = inference.TwoValueTest(all_segs_2010[5], all_segs_2022[5], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_6 = inference.TwoValueTest(all_segs_2010[6], all_segs_2022[6], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_7 = inference.TwoValueTest(all_segs_2010[7], all_segs_2022[7], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_8 = inference.TwoValueTest(all_segs_2010[8], all_segs_2022[8], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)

render_plots_as_grid_and_save([compare_0,compare_1,compare_2,compare_3,compare_4,compare_5,compare_6,compare_7,compare_8,], filename=graph_file_name)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 11
#       9 compare_random_label_3 = inference.TwoValueTest(all_segs_2010[3], all_segs_2022[3], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
#      10 compare_random_label_4 = inference.TwoValueTest(all_segs_2010[4], all_segs_2022[4], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
# ---> 11 compare_random_label_5 = inference.TwoValueTest(all_segs_2010[5], all_segs_2022[5], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
#      12 compare_random_label_6 = inference.TwoValueTest(all_segs_2010[6], all_segs_2022[6], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
#      13 compare_random_label_7 = inference.TwoValueTest(all_segs_2010[7], all_segs_2022[7], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
#
# File ~\anaconda3\Lib\site-packages\segregation\inference\inference_wrappers.py:580, in TwoValueTest.__init__(self, seg_class_1, seg_class_2, iterations_under_null, null_approach, n_jobs, backend, index_kwargs_1, index_kwargs_2, **kwargs)
#     568 def __init__(
#     569     self,
#     570     seg_class_1,
#    (...)    578     **kwargs,
#     579 ):
# --> 580     aux = _compare_segregation(
#     581         seg_class_1,
#     582         seg_class_2,
#     583         iterations=iterations_under_null,
#     584         null_approach=null_approach,
#     585         n_jobs=n_jobs,
#     586         backend=backend,
#     587         index_kwargs_1=index_kwargs_1,
#     588         index_kwargs_2=index_kwargs_2,
#     589     )
#     591     self.p_value = aux[0]
#     592     self.est_sim = aux[1]
#
# File ~\anaconda3\Lib\site-packages\segregation\inference\inference_wrappers.py:419, in _compare_segregation(seg_class_1, seg_class_2, iterations, null_approach, index_kwargs_1, index_kwargs_2, n_jobs, backend)
#     415         groups = None
#     417     stacked = _prepare_random_label(seg_class_1, seg_class_2)
# --> 419     estimates = Parallel(n_jobs=n_jobs, backend=backend)(
#     420         delayed(_estimate_random_label_difference)(
#     421             (
#     422                 stacked,
#     423                 seg_class_1._function,
#     424                 index_kwargs_1,
#     425                 index_kwargs_2,
#     426                 seg_class_1.index_type,
#     427                 groups,
#     428                 null_approach,
#     429             )
#     430         )
#     431         for i in tqdm(range(iterations))
#     432     )
#     434 if null_approach in [
#     435     "composition",
#     436     "share",
#     437     "dual_composition",
#     438 ]:
#     439     if isinstance(seg_class_1, MultiGroupIndex):
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %%
approach = 'bootstrap'
graph_file_name = f"grid_plot_{municipio}_{approach}_2010_vs_2022.png"

compare_0 = inference.TwoValueTest(all_segs_2010[0], all_segs_2022[0], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_1 = inference.TwoValueTest(all_segs_2010[1], all_segs_2022[1], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_2 = inference.TwoValueTest(all_segs_2010[2], all_segs_2022[2], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_3 = inference.TwoValueTest(all_segs_2010[3], all_segs_2022[3], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_4 = inference.TwoValueTest(all_segs_2010[4], all_segs_2022[4], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_5 = inference.TwoValueTest(all_segs_2010[5], all_segs_2022[5], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_6 = inference.TwoValueTest(all_segs_2010[6], all_segs_2022[6], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_7 = inference.TwoValueTest(all_segs_2010[7], all_segs_2022[7], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_8 = inference.TwoValueTest(all_segs_2010[8], all_segs_2022[8], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)

render_plots_as_grid_and_save([compare_0,compare_1,compare_2,compare_3,compare_4,compare_5,compare_6,compare_7,compare_8,], filename=graph_file_name)

# %%
approach = 'composition'
graph_file_name = f"grid_plot_{municipio}_{approach}_2010_vs_2022.png"

compare_0 = inference.TwoValueTest(all_segs_2010[0], all_segs_2022[0], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_1 = inference.TwoValueTest(all_segs_2010[1], all_segs_2022[1], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_2 = inference.TwoValueTest(all_segs_2010[2], all_segs_2022[2], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_3 = inference.TwoValueTest(all_segs_2010[3], all_segs_2022[3], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_4 = inference.TwoValueTest(all_segs_2010[4], all_segs_2022[4], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_5 = inference.TwoValueTest(all_segs_2010[5], all_segs_2022[5], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_6 = inference.TwoValueTest(all_segs_2010[6], all_segs_2022[6], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_7 = inference.TwoValueTest(all_segs_2010[7], all_segs_2022[7], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
compare_8 = inference.TwoValueTest(all_segs_2010[8], all_segs_2022[8], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)

render_plots_as_grid_and_save([compare_0,compare_1,compare_2,compare_3,compare_4,compare_5,compare_6,compare_7,compare_8,], filename=graph_file_name)
