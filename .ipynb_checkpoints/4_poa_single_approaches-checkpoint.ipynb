# %%
# %run ./utils.ipynb

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
n_iteracoes = 500
n_jobs = -1
backend = "loky"

# %%
csv_path = "Agregados_por_setores_cor_ou_raca_BR_csv/Agregados_por_setores_cor_ou_raca_BR.csv"

# %%
estado = 'RS'
municipio = '4314902' # Porto Alegre
#municipio = '4314100' # Passo Fundo
dummy_dinamico = False

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
merged_df = process_mun(shp_path, csv_path, municipio)
all_segs_mun = calculate_seg(merged_df)
# Out:
# Dissimilarity: 0.36938877371482537
# Spatial Dissimilarity: 0.2862184030564052
# Gini: 0.48854095748836385
# Entropy: 0.12980799191107342
# Isolation: 0.36469467525756316
# Dist. Decay Isolation: 0.32391461781522224
# Rel. Concentration: -0.10650809891200008
# Rel. Centralization: -0.10156531362133592
# Rel. Clustering: 0.5956711862979596

# %%
approach = "systematic"
graph_file_name = f"grid_plot_{municipio}_{approach}.png"

mun_0 = inference.SingleValueTest(all_segs_mun[0], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_1 = inference.SingleValueTest(all_segs_mun[1], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_2 = inference.SingleValueTest(all_segs_mun[2], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_3 = inference.SingleValueTest(all_segs_mun[3], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_4 = inference.SingleValueTest(all_segs_mun[4], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_5 = inference.SingleValueTest(all_segs_mun[5], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_6 = inference.SingleValueTest(all_segs_mun[6], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_7 = inference.SingleValueTest(all_segs_mun[7], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_8 = inference.SingleValueTest(all_segs_mun[8], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)

render_plots_as_grid_and_save([mun_0, mun_1, mun_2, mun_3, mun_4, mun_5, mun_6, mun_7, mun_8], filename=graph_file_name)
# Out:
# ...
#   0%|          | 0/500 [00:00<?, ?it/s]
# Figure saved to: C:\Users\renan\OneDrive\Documentos\GitHub\segregation_brazil_pysal\grid_plot_4314902_systematic.png

# %%
approach = "evenness"
graph_file_name = f"grid_plot_{municipio}_{approach}.png"

mun_0 = inference.SingleValueTest(all_segs_mun[0], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_1 = inference.SingleValueTest(all_segs_mun[1], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_2 = inference.SingleValueTest(all_segs_mun[2], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_3 = inference.SingleValueTest(all_segs_mun[3], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_4 = inference.SingleValueTest(all_segs_mun[4], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_5 = inference.SingleValueTest(all_segs_mun[5], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_6 = inference.SingleValueTest(all_segs_mun[6], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_7 = inference.SingleValueTest(all_segs_mun[7], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_8 = inference.SingleValueTest(all_segs_mun[8], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)

render_plots_as_grid_and_save([mun_0, mun_1, mun_2, mun_3, mun_4, mun_5, mun_6, mun_7, mun_8], filename=graph_file_name)
# Out:
# ...
#   0%|          | 0/500 [00:00<?, ?it/s]
# Figure saved to: C:\Users\renan\OneDrive\Documentos\GitHub\segregation_brazil_pysal\grid_plot_4314902_evenness.png

# %%
approach = "geographic_permutation"
graph_file_name = f"grid_plot_{municipio}_{approach}.png"

#mun_0 = inference.SingleValueTest(all_segs_mun[0], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_1 = inference.SingleValueTest(all_segs_mun[1], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
#mun_2 = inference.SingleValueTest(all_segs_mun[2], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
#mun_3 = inference.SingleValueTest(all_segs_mun[3], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
#mun_4 = inference.SingleValueTest(all_segs_mun[4], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_5 = inference.SingleValueTest(all_segs_mun[5], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_6 = inference.SingleValueTest(all_segs_mun[6], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_7 = inference.SingleValueTest(all_segs_mun[7], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_8 = inference.SingleValueTest(all_segs_mun[8], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)

render_plots_as_grid_and_save([mun_1, mun_5, mun_6, mun_7, mun_8], filename=graph_file_name)
# Out:
# ...
#   0%|          | 0/500 [00:00<?, ?it/s]
# Figure saved to: C:\Users\renan\OneDrive\Documentos\GitHub\segregation_brazil_pysal\grid_plot_4314902_geographic_permutation.png

# %%
approach = "bootstrap"
graph_file_name = f"grid_plot_{municipio}_{approach}.png"

mun_0 = inference.SingleValueTest(all_segs_mun[0], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_1 = inference.SingleValueTest(all_segs_mun[1], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_2 = inference.SingleValueTest(all_segs_mun[2], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_3 = inference.SingleValueTest(all_segs_mun[3], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_4 = inference.SingleValueTest(all_segs_mun[4], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_5 = inference.SingleValueTest(all_segs_mun[5], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_6 = inference.SingleValueTest(all_segs_mun[6], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_7 = inference.SingleValueTest(all_segs_mun[7], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
mun_8 = inference.SingleValueTest(all_segs_mun[8], null_approach=approach, iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)

render_plots_as_grid_and_save([mun_0, mun_1, mun_2, mun_3, mun_4, mun_5, mun_6, mun_7, mun_8], filename=graph_file_name)
# Out:
# Figure saved to: C:\Users\renan\OneDrive\Documentos\GitHub\segregation_brazil_pysal\grid_plot_4314902_bootstrap.png
