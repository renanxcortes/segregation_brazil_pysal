# %%
import pyproj
import geopandas as gpd
import pandas as pd
import contextily as cx
import matplotlib.pyplot as plt

# %%
filepath = "RS_setores_CD2022/RS_setores_CD2022.shp"
gdf = gpd.read_file(filepath)
# Out:
# C:\Users\renan\anaconda3\Lib\site-packages\pyogrio\core.py:36: RuntimeWarning: Could not detect PROJ data files. Set PROJ_LIB environment variable to the correct path.
#   _init_proj_data()

# %%
gdf_cidade = gdf[gdf['CD_MUN'] == '4314100']

# %%
# Define the list of column names you want to read
desired_columns = [
    'CD_SETOR', 
    'V01317', 
    'V01318', 
    'V01319', 
    'V01320', 
    'V01321'
]

# Read the CSV file, loading only the specified columns
df = pd.read_csv('Agregados_por_setores_cor_ou_raca_BR_csv/Agregados_por_setores_cor_ou_raca_BR.csv', sep = ';', usecols=desired_columns)

# Display the resulting DataFrame to verify
print(df.head())
# Out:
#           CD_SETOR V01317 V01318 V01319 V01320 V01321
# 0  110001505000002    312     87      X    514     13
# 1  110001505000003    189     25      0    336      6
# 2  110001505000004     71     14      0    135      X
# 3  110001505000006    255     54      X    460     14
# 4  110001505000007    229     49      X    459     10
# C:\Users\renan\AppData\Local\Temp\ipykernel_49496\3889989446.py:12: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Agregados_por_setores_cor_ou_raca_BR_csv/Agregados_por_setores_cor_ou_raca_BR.csv', sep = ';', usecols=desired_columns)

# %%
df['CD_SETOR'] = df['CD_SETOR'].astype('str')

# %%
merged_gdf = gdf_cidade.merge(
    df,
    on='CD_SETOR',  # Join on CD_SETOR column
    how='left'      # Use left join to keep all records from gdf_poa
)

# %%
cols_to_clean = ['V01317', 'V01318', 'V01319', 'V01320', 'V01321']
merged_gdf[cols_to_clean] = merged_gdf[cols_to_clean].replace('X', 0)
merged_gdf = merged_gdf.fillna(0)

# %%
merged_gdf[cols_to_clean] = merged_gdf[cols_to_clean].astype('int64')

# %%
merged_gdf['pop_total'] = merged_gdf[cols_to_clean].sum(axis=1)
# Percentual de pretos e pardos
merged_gdf['pp_total'] = merged_gdf['V01318'] + merged_gdf['V01320']
merged_gdf['ppp'] = merged_gdf['pp_total'] / merged_gdf['pop_total']

# %% [markdown]
# ## Mapa Estático

# %%
# Create the plot and get the axes object
ax = merged_gdf.to_crs(epsg=3857).plot(
    column='ppp',      # The name of the numeric column to use for coloring
    cmap='YlOrRd',        # The colormap to use (viridis is a good default or YlOrRd)
    legend=True,           # Display the color bar legend
    figsize=(10, 10)        # Optional: control the figure size
)

# Add the basemap
cx.add_basemap(ax)

# Optional: Customize or remove the axis for a cleaner map
# ax.set_axis_off()

plt.show()

# %% [markdown]
# ## Mapa Dinâmico

# %%
merged_gdf[['geometry', 'NM_BAIRRO', 'ppp']].to_crs(epsg=3857).explore(
    column="ppp", # Column to use for coloring the map
    tooltip=False,         # Show all data columns on hover
    popup=True,           # Show all data columns on click
    cmap="YlOrRd",       # Color map
    tiles="OpenStreetMap" # Base map tiles
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64fd78e39641301f937807dcc9d80a78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64fd78e39641301f937807dcc9d80a78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64fd78e39641301f937807dcc9d80a78 = L.map(
#                 &quot;map_64fd78e39641301f937807dcc9d80a78&quot;,
#                 {
#                     center: [-28.26619699999994, -52.445042049999955],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_64fd78e39641301f937807dcc9d80a78);
#
#
#
#
#
#             var tile_layer_889ef1d0cc7ddfef933de055f584e239 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_889ef1d0cc7ddfef933de055f584e239.addTo(map_64fd78e39641301f937807dcc9d80a78);
#
#
#             map_64fd78e39641301f937807dcc9d80a78.fitBounds(
#                 [[-28.41225089999994, -52.67712349999994], [-28.12014309999994, -52.21296059999997]],
#                 {}
#             );
#
#
#         function geo_json_07509f2f60551cb5e35f141c08cf2873_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;66&quot;: case &quot;179&quot;: case &quot;181&quot;: case &quot;211&quot;: case &quot;219&quot;: case &quot;284&quot;: case &quot;313&quot;:
#                     return {&quot;color&quot;: &quot;#ffffcc&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;155&quot;: case &quot;208&quot;: case &quot;280&quot;:
#                     return {&quot;color&quot;: &quot;#febf5a&quot;, &quot;fillColor&quot;: &quot;#febf5a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;6&quot;: case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#ffeda0&quot;, &quot;fillColor&quot;: &quot;#ffeda0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;151&quot;:
#                     return {&quot;color&quot;: &quot;#fedb7a&quot;, &quot;fillColor&quot;: &quot;#fedb7a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;87&quot;: case &quot;205&quot;: case &quot;232&quot;:
#                     return {&quot;color&quot;: &quot;#fee084&quot;, &quot;fillColor&quot;: &quot;#fee084&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;41&quot;: case &quot;203&quot;:
#                     return {&quot;color&quot;: &quot;#ffe691&quot;, &quot;fillColor&quot;: &quot;#ffe691&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;36&quot;: case &quot;45&quot;:
#                     return {&quot;color&quot;: &quot;#ffefa5&quot;, &quot;fillColor&quot;: &quot;#ffefa5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#fff3af&quot;, &quot;fillColor&quot;: &quot;#fff3af&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;109&quot;:
#                     return {&quot;color&quot;: &quot;#ffe793&quot;, &quot;fillColor&quot;: &quot;#ffe793&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;212&quot;:
#                     return {&quot;color&quot;: &quot;#fed572&quot;, &quot;fillColor&quot;: &quot;#fed572&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;: case &quot;48&quot;: case &quot;98&quot;: case &quot;157&quot;: case &quot;234&quot;:
#                     return {&quot;color&quot;: &quot;#ffe998&quot;, &quot;fillColor&quot;: &quot;#ffe998&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&qu

# %% [markdown]
# ## Cálculo de Medidas de Segregação

# %%
from segregation.singlegroup import Dissim, Isolation, RelativeConcentration, RelativeCentralization, RelativeClustering
from segregation import inference

# %%
merged_gdf = merged_gdf.to_crs(epsg=3857)

# %%
dissim = Dissim(merged_gdf, group_pop_var='pp_total', total_pop_var='pop_total')
isol = Isolation(merged_gdf, group_pop_var='pp_total', total_pop_var='pop_total')
conc = RelativeConcentration(merged_gdf, group_pop_var='pp_total', total_pop_var='pop_total')
cent = RelativeCentralization(merged_gdf, group_pop_var='pp_total', total_pop_var='pop_total')
clust = RelativeClustering(merged_gdf, group_pop_var='pp_total', total_pop_var='pop_total')

# %%
print(dissim.statistic)
print(isol.statistic)
print(conc.statistic)
print(cent.statistic)
print(clust.statistic)
# Out:
# 0.25775533478155566
# 0.2710588076926712
# -0.03860490819187214
# -0.16967125513632197
# 0.4276840293778372

# %%
rside_test = inference.SingleValueTest(dissim, null_approach='evenness')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
rside_test.p_value
# Out:
# np.float64(0.0)

# %%
rside_test.plot()
# Out:
# <Axes: title={'center': 'Dissim (Value = 0.258)'}, ylabel='Count'>
