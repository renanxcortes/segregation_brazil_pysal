# %%
# %run ./utils.ipynb

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
csv_path = "Agregados_por_setores_cor_ou_raca_BR_csv/Agregados_por_setores_cor_ou_raca_BR.csv"

# %%
estado = 'RS'
municipio = '4314902'
dummy_dinamico = False

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
merged_df = process_mun(shp_path, csv_path, municipio)
all_segs_poa = calculate_seg(merged_df)
# Out:
# Dissimilarity: 0.36938877371482537
# Spatial Dissimilarity: 0.2862184030564052
# Gini: 0.48854095748836385
# Entropy: 0.12980799191107342
# Isolation: 0.36469467525756316
# Dist. Decay Isolation: 0.32391461781522224
# Rel. Concentration: -0.10650809891200008
# Rel. Centralization: -0.10156531362133592
# Rel. Clustering: 0.5956711862979596

# %%
estado = 'MG'
municipio = '3106200'
dummy_dinamico = False

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
merged_df = process_mun(shp_path, csv_path, municipio)
all_segs_bh = calculate_seg(merged_df)
# Out:
# Dissimilarity: 0.35021414807515844
# Spatial Dissimilarity: 0.2586190128446201
# Gini: 0.4688072276234917
# Entropy: 0.13291743725484428
# Isolation: 0.6371511245689692
# Dist. Decay Isolation: 0.607040098693925
# Rel. Concentration: -0.10820249686750398
# Rel. Centralization: -0.23376004234933134
# Rel. Clustering: 0.05068193006799282

# %%
#help(inference.TwoValueTest)

# %%
n_iteracoes = 20
n_jobs = -1
backend = "loky"

poa_bh_test_label_0 = inference.TwoValueTest(all_segs_poa[0], all_segs_bh[0], null_approach='random_label', iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
poa_bh_test_label_1 = inference.TwoValueTest(all_segs_poa[1], all_segs_bh[1], null_approach='random_label', iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
poa_bh_test_label_2 = inference.TwoValueTest(all_segs_poa[2], all_segs_bh[2], null_approach='random_label', iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
poa_bh_test_label_3 = inference.TwoValueTest(all_segs_poa[3], all_segs_bh[3], null_approach='random_label', iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
poa_bh_test_label_4 = inference.TwoValueTest(all_segs_poa[4], all_segs_bh[4], null_approach='random_label', iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
poa_bh_test_label_5 = inference.TwoValueTest(all_segs_poa[5], all_segs_bh[5], null_approach='random_label', iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
poa_bh_test_label_6 = inference.TwoValueTest(all_segs_poa[6], all_segs_bh[6], null_approach='random_label', iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
poa_bh_test_label_7 = inference.TwoValueTest(all_segs_poa[7], all_segs_bh[7], null_approach='random_label', iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
poa_bh_test_label_8 = inference.TwoValueTest(all_segs_poa[8], all_segs_bh[8], null_approach='random_label', iterations_under_null=n_iteracoes, n_jobs = n_jobs, backend = backend)
# Out:
# ...
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(3, 3, figsize=(15, 12)) # Largura Altura

# Flatten axes (no row/col indexing, no loops)
ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9 = axs.ravel()

poa_bh_test_label_0.plot(ax=ax1)
poa_bh_test_label_1.plot(ax=ax2)
poa_bh_test_label_2.plot(ax=ax3)
poa_bh_test_label_3.plot(ax=ax4)
poa_bh_test_label_4.plot(ax=ax5)
poa_bh_test_label_5.plot(ax=ax6)
poa_bh_test_label_6.plot(ax=ax7)
poa_bh_test_label_7.plot(ax=ax8)
poa_bh_test_label_8.plot(ax=ax9)

plt.tight_layout()
plt.show()
