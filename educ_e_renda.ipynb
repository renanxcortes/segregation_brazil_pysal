# %%
# %run ./utils.ipynb

# %%
csv_path = "Agregados_por_setores_cor_ou_raca_BR_csv/Agregados_por_setores_cor_ou_raca_BR.csv"

# %%
df = pd.read_csv(csv_path, sep = ';')
# Out:
# C:\Users\renan\AppData\Local\Temp\ipykernel_11104\4072567546.py:1: DtypeWarning: Columns (1,4,6,9,11,14,19,41,42,46,51,52,55,56,62,66,69,75,81,84,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, sep = ';')

# %%
len(df.columns)
# Out:
# 96

# %%
df.columns
# Out:
# Index(['CD_SETOR', 'V01317', 'V01318', 'V01319', 'V01320', 'V01321', 'V01322',
#        'V01323', 'V01324', 'V01325', 'V01326', 'V01327', 'V01328', 'V01329',
#        'V01330', 'V01331', 'V01332', 'V01333', 'V01334', 'V01335', 'V01336',
#        'V01337', 'V01338', 'V01339', 'V01340', 'V01341', 'V01342', 'V01343',
#        'V01344', 'V01345', 'V01346', 'V01347', 'V01348', 'V01349', 'V01350',
#        'V01351', 'V01352', 'V01353', 'V01354', 'V01355', 'V01356', 'V01357',
#        'V01358', 'V01359', 'V01360', 'V01361', 'V01362', 'V01363', 'V01364',
#        'V01365', 'V01366', 'V01367', 'V01368', 'V01369', 'V01370', 'V01371',
#        'V01372', 'V01373', 'V01374', 'V01375', 'V01376', 'V01377', 'V01378',
#        'V01379', 'V01380', 'V01381', 'V01382', 'V01383', 'V01384', 'V01385',
#        'V01386', 'V01387', 'V01388', 'V01389', 'V01390', 'V01391', 'V01392',
#        'V01393', 'V01394', 'V01395', 'V01396', 'V01397', 'V01398', 'V01399',
#        'V01400', 'V01401', 'V01402', 'V01403', 'V01404', 'V01405', 'V01406',
#        'V01407', 'V01408', 'V01409', 'V01410', 'V01411'],
#       dtype='object')
