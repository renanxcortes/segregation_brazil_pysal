# %%
# %run ./utils.ipynb

# %%
csv_path = "Agregados_por_setores_cor_ou_raca_BR_csv/Agregados_por_setores_cor_ou_raca_BR.csv"

# %%
dummy_dinamico = True

# %% [markdown]
# # Porto Alegre

# %%
estado = 'RS'
municipio = '4314902'

shp_path = f"{estado}_setores_CD2022/{estado}_setores_CD2022.shp"
seg_profile_mun(shp_path, csv_path, municipio, plot_dinamico = dummy_dinamico)
# Out:
# C:\Users\renan\anaconda3\Lib\site-packages\pyogrio\core.py:36: RuntimeWarning: Could not detect PROJ data files. Set PROJ_LIB environment variable to the correct path.
#   _init_proj_data()
# C:\Users\renan\AppData\Local\Temp\ipykernel_48196\3701015944.py:15: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path, sep = ';', usecols=desired_columns)
# C:\Users\renan\AppData\Local\Temp\ipykernel_48196\3701015944.py:23: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_gdf = merged_gdf.fillna(0)
# C:\Users\renan\anaconda3\Lib\site-packages\segregation\singlegroup\spatial_dissim.py:48: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w_object = Queen.from_dataframe(data)
# Dissimilarity: 0.36938877371482537
# Spatial Dissimilarity: 0.2862184030564052
# Gini: 0.48854095748836385
# Entropy: 0.12980799191107342
# Isolation: 0.36469467525756316
# Dist. Decay Isolation: 0.32391461781522224
# Rel. Concentration: -0.10650809891200008
# Rel. Centralization: -0.10156531362133592
# Rel. Clustering: 0.5956711862979596
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86e967b92d22ffe891e1f4f4750924d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86e967b92d22ffe891e1f4f4750924d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86e967b92d22ffe891e1f4f4750924d4 = L.map(
#                 &quot;map_86e967b92d22ffe891e1f4f4750924d4&quot;,
#                 {
#                     center: [-30.10085794999997, -51.15759369999995],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_86e967b92d22ffe891e1f4f4750924d4);
#
#
#
#
#
#             var tile_layer_966c95226180eca28a64eeade8403ad7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_966c95226180eca28a64eeade8403ad7.addTo(map_86e967b92d22ffe891e1f4f4750924d4);
#
#
#             map_86e967b92d22ffe891e1f4f4750924d4.fitBounds(
#                 [[-30.269413699999973, -51.303245199999935], [-29.93230219999997, -51.011942199999964]],
#                 {}
#             );
#
#
#         function geo_json_91f8e898564ab1c73b09965f3f0596f5_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;506&quot;: case &quot;898&quot;: case &quot;906&quot;: case &quot;953&quot;: case &quot;957&quot;: case &quot;972&quot;: case &quot;1073&quot;: case &quot;1096&quot;: case &quot;1516&quot;: case &quot;1667&quot;: case &quot;1820&quot;: case &quot;2011&quot;: case &quot;2397&quot;: case &quot;2461&quot;: case &quot;2547&quot;: case &quot;2558&quot;: case &quot;2581&quot;: case &quot;2678&quot;:
#                     return {&quot;color&quot;: &quot;#feda78&quot;, &quot;fillColor&quot;: &quot;#feda78&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;78&quot;: case &quot;122&quot;: case &quot;264&quot;: case &quot;527&quot;: case &quot;566&quot;: case &quot;610&quot;: case &quot;615&quot;: case &quot;946&quot;: case &quot;977&quot;: case &quot;1423&quot;: case &quot;1444&quot;: case &quot;1531&quot;: case &quot;1578&quot;: case &quot;1581&quot;: case &quot;1604&quot;: case &quot;1649&quot;: case &quot;1682&quot;: case &quot;1722&quot;: case &quot;1912&quot;: case &quot;2087&quot;: case &quot;2370&quot;: case &quot;2645&quot;:
#                     return {&quot;color&quot;: &quot;#ffe998&quot;, &quot;fillColor&quot;: &quot;#ffe998&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;221&quot;: case &quot;361&quot;: case &quot;454&quot;: case &quot;505&quot;: case &quot;542&quot;: case &quot;545&quot;: case &quot;989&quot;: case &quot;1000&quot;: case &quot;1046&quot;: case &quot;1186&quot;: case &quot;1192&quot;: case &quot;1204&quot;: case &quot;1545&quot;: case &quot;1550&quot;: case &quot;1566&quot;: case &quot;1676&quot;: case &quot;2457&quot;: case &quot;2496&quot;: case &quot;2511&quot;:
#                     return {&quot;color&quot;: &quot;#ffe895&quot;, &quot;fillColor&quot;: &quot;#ffe895&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;23&quot;: case &quot;48&quot;: case &quot;99&quot;: case &quot;466&quot;: case &quot;514&quot;: case &quot;518&quot;: case &quot;546&quot;: case &quot;550&quot;: case &quot;773&quot;: case &quot;899&quot;: case &quot;945&quot;: case &quot;994&quot;: case &quot;1179&quot;: case &quot;1216&quot;: case &quot;1439&quot;: case &quot;1449&quot;: case &quot;1636&quot;: case &quot;1691&quot;: case &quot;2291&quot;: case &quot;2596&quot;:
#                     return {&quot;color&quot;: &quot;#ffe48c&quot;, &quot;fillColor&quot;: &quot;#ffe48c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;33&quot;: case &quot;129&quot;: case &quot;346&quot;: case &quot;406&quot;: case &quot;494&quot;: case &quot;958&quot;: case &quot;1128&quot;: case &quot;1657&quot;: cas
